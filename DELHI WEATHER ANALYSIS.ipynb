# %%
#importing all required libraries

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import scipy.stats
import seaborn as sns
import datetime
from pylab import rcParams
# %matplotlib inline

# %% [markdown]
# # Importing the original data set:

# %%
#Importing the data set
data = pd.read_csv("dataset.csv",parse_dates=['datetime_utc'],skipinitialspace=True)
len(data)
# Out:
# 100990

# %%
data
# Out:
#               datetime_utc              _conds  _dewptm  _fog  _hail  \
# 0      1996-11-01 11:00:00               Smoke      9.0     0      0
# 1      1996-11-01 12:00:00               Smoke     10.0     0      0
# 2      1996-11-01 13:00:00               Smoke     11.0     0      0
# 3      1996-11-01 14:00:00               Smoke     10.0     0      0
# 4      1996-11-01 16:00:00               Smoke     11.0     0      0
# 5      1996-11-01 17:00:00               Smoke     12.0     0      0
# 6      1996-11-01 18:00:00               Smoke     13.0     0      0
# 7      1996-11-01 19:00:00               Smoke     13.0     0      0
# 8      1996-11-01 20:00:00               Smoke     13.0     0      0
# 9      1996-11-01 21:00:00               Smoke     13.0     0      0
# 10     1996-11-01 22:00:00               Smoke     13.0     0      0
# 11     1996-11-01 23:00:00               Smoke     12.0     0      0
# 12     1996-11-02 00:00:00               Smoke     11.0     0      0
# ...

# %% [markdown]
# # Date Cleaning

# %%
#The codes for cleaning are in
#cleaning1.py
#cleaning2.py and
#cleaning3.py

# %% [markdown]
# # After cleaning we get the data set:

# %%
delhi = pd.read_csv("trail2.csv",parse_dates=['datetime_utc'],skipinitialspace=True)

# %%
delhi
# Out:
#               datetime_utc              _conds  _dewptm  _fog  _heatindexm  \
# 0      1996-11-01 11:00:00               Smoke      9.0     0          NaN
# 1      1996-11-01 12:00:00               Smoke     10.0     0          NaN
# 2      1996-11-01 13:00:00               Smoke     11.0     0          NaN
# 3      1996-11-01 14:00:00               Smoke     10.0     0          NaN
# 4      1996-11-01 16:00:00               Smoke     11.0     0          NaN
# 5      1996-11-01 17:00:00               Smoke     12.0     0          NaN
# 6      1996-11-01 18:00:00               Smoke     13.0     0          NaN
# 7      1996-11-01 19:00:00               Smoke     13.0     0          NaN
# 8      1996-11-01 20:00:00               Smoke     13.0     0          NaN
# 9      1996-11-01 21:00:00               Smoke     13.0     0          NaN
# 10     1996-11-01 22:00:00               Smoke     13.0     0          NaN
# ...

# %% [markdown]
# # Converting DateTime_UTC to a workable format:

# %%
#Converting date to a readable and workable form
delhi['Date'] = pd.to_datetime(delhi['datetime_utc'])
delhi['year'] = delhi['Date'].dt.year
delhi['month'] = delhi['Date'].dt.month
delhi['day'] = delhi['Date'].dt.day
delhi['hour'] = delhi['Date'].dt.hour
delhi#This is to show the date, year, month and hour.
# Out:
#               datetime_utc              _conds  _dewptm  _fog  _heatindexm  \
# 0      1996-11-01 11:00:00               Smoke      9.0     0          NaN
# 1      1996-11-01 12:00:00               Smoke     10.0     0          NaN
# 2      1996-11-01 13:00:00               Smoke     11.0     0          NaN
# 3      1996-11-01 14:00:00               Smoke     10.0     0          NaN
# 4      1996-11-01 16:00:00               Smoke     11.0     0          NaN
# 5      1996-11-01 17:00:00               Smoke     12.0     0          NaN
# 6      1996-11-01 18:00:00               Smoke     13.0     0          NaN
# 7      1996-11-01 19:00:00               Smoke     13.0     0          NaN
# 8      1996-11-01 20:00:00               Smoke     13.0     0          NaN
# 9      1996-11-01 21:00:00               Smoke     13.0     0          NaN
# 10     1996-11-01 22:00:00               Smoke     13.0     0          NaN
# ...

# %% [markdown]
# # Creating a Simple Random Sample:

# %%
delhi_sample = delhi.sample(frac =.01) 
delhi_sample=delhi_sample.sort_index()
delhi_sample
delhi_sample.to_csv(r'C:\Users\Dell\IDS_project\IDS_project\sample.csv')

# %% [markdown]
# # Data Normalization:

# %%
# Create x, where x the 'scores' column's values as floats
x = delhi_sample[['_dewptm','_heatindexm','_hum','_pressurem','_tempm','_vism','_wdird','_wspdm']].values.astype(float)
from sklearn import preprocessing
# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
x_scaled = min_max_scaler.fit_transform(x)

# Run the normalizer on the dataframe
delhi_sample_normalized = pd.DataFrame(x_scaled)


delhi_sample_normalized
delhi_sample_normalized.to_csv(r'C:\Users\Dell\IDS_project\IDS_project\sample_normalized.csv')

# %%
delhi_normalized=pd.read_csv("sample_normalized.csv",parse_dates=['datetime_utc'],skipinitialspace=True)

# %% [markdown]
# # Before Normalization:

# %%
#Have used graphing tool Orange3 for visualization
from PIL import Image 
# Read image 
img = Image.open('2.png') 
# Output Images 
img.show()

# %% [markdown]
# # After Normalization:

# %%
#Have used graphing tool Orange3 for visualization
# Read image 
img = Image.open('1.png') 
  
# Output Images 
img.show()

# %% [markdown]
# # From this we can see that both the graphs are identical.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # A graph of most common weather conditions in delhi:

# %%
# Lets plot top 10 weather condition in delhi.
plt.figure(figsize=(15, 10));
delhi._conds.value_counts().head(10).plot(kind='bar');
plt.title("Top 10 most common weather condition")
plt.plot();
# We can clearly see that haze and smoke are the most common weather condition in delhi.

# %% [markdown]
# # For sample:

# %%
#This is for sample
# Lets plot top 10 weather condition in delhi.
plt.figure(figsize=(15, 10));
delhi_sample._conds.value_counts().head(10).plot(kind='bar');
plt.title("Top 10 most common weather condition")
plt.plot();

# %% [markdown]
# # The distribution is similar showing that our sample is a good representaion of the population.

# %% [markdown]
# # The most common wind directions in delhi:
# ## For population:

# %%
plt.figure(figsize=(15, 10));
plt.title("Common wind direction in delhi");
delhi._wdire.value_counts().plot(kind="bar");
plt.plot();

# %% [markdown]
# # # For sample:

# %%
#This is for sample
plt.figure(figsize=(15, 10));
plt.title("Common wind direction in delhi");
delhi_sample._wdire.value_counts().plot(kind="bar");
plt.plot();

# %% [markdown]
# # # From these above 2 distributions we can see that the rise of pollution in delhi is because of the winds blowing from Punjab and Haryana.

# %% [markdown]
# # The distribution to show the average temperature year on year:

# %%
##Delhi Average Temperature by year
year_temp = data.groupby(delhi.year).mean()
year_temp._tempm.ewm(com= 5)
year_temp._tempm.plot(linewidth=1)
plt.title('Delhi Average Temperature by year')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# For Sample:

# %%
##Delhi Average Temperature by year from a sample
year_temp = delhi_sample.groupby(delhi_sample.year).mean()
year_temp._tempm.ewm(com= 5)
year_temp._tempm.plot(linewidth=1)
plt.title('Delhi Average Temperature by year')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# In These distributions we can see that the average temperature on a yearly basis in within the range 23-28 for the population and within 22-28 for the sample chosen.

# %% [markdown]
# # Year on Year Average Heat Index:

# %% [markdown]
# For Population:

# %%
year_heat = delhi.groupby(delhi.year).mean()
year_heat._heatindexm.ewm(com =5)
year_heat._heatindexm.plot(linewidth=1)
plt.title('Delhi Average Heat by year')
plt.xlabel('year')
# Out:
# Text(0.5, 0, 'year')

# %%
year_heat = delhi_sample.groupby(delhi_sample.year).mean()
year_heat._heatindexm.ewm(com =5)
year_heat._heatindexm.plot(linewidth=1)
plt.title('Delhi Average Heat by year')
plt.xlabel('year')
# Out:
# Text(0.5, 0, 'year')

# %% [markdown]
# With a simple search on google we can see that average heat in delhi grew by close to 3.5 to 4 in 2010 because of air pollution it started cleating localized hot spots.
# 2010 April saw a huge spike in temperature.

# %%
delhi=pd.read_csv("sample.csv")
sns.catplot(x="_vism", y="_conds",kind="bar", data=delhi);

# %% [markdown]
# # Correlation between the quantities:

# %%
p = delhi.corr(method='pearson')
sns.heatmap(p,xticklabels=p.columns,yticklabels=p.columns,cmap='RdBu',annot=True,linewidth=0.5,fmt='0.1f')

# %% [markdown]
# From this we can see that the highest correlation is between heat index and temperature i.e 60%.

# %%
s = delhi.corr(method='spearman')
sns.heatmap(s,xticklabels=s.columns,yticklabels=s.columns,cmap='coolwarm',annot=True,linewidth=0.5,fmt='0.1f')

# %% [markdown]
# Even in the method Spearman we get the same correlation.

# %%
k = delhi.corr(method='kendall')
sns.heatmap(k,xticklabels=k.columns,yticklabels=k.columns,cmap='winter',annot=True,linewidth=0.5,fmt='0.1f')

# %% [markdown]
# This method shows a correlation of 40% between heatindex, dew point temperature and temperature.

# %% [markdown]
# The dewpoint temperature is the temperature at which the air can no longer "hold" all of the water vapor which is mixed with it, and some of the water vapor must condense into liquid water. The dew point is always lower than (or equal to) the air temperature.

# %% [markdown]
# # Hypothesis testing:

# %% [markdown]
# Null Hypothesis: There is no  relationship between the condition and the wind direction.
# Alternate Hypothesis: There is a relation between condition and wind direction.

# %%
from scipy import stats
from scipy.stats import chi2
df_chi = pd.read_csv('sample.csv')
contingency_table=pd.crosstab(df_chi["_conds"],df_chi["_wdire"])

Observed_Values = contingency_table.values 

b=stats.chi2_contingency(contingency_table)
Expected_Values = b[3]

no_of_rows=len(contingency_table.iloc[0:2,0])
no_of_columns=len(contingency_table.iloc[0,0:2])
ddof=(no_of_rows-1)*(no_of_columns-1)
print("Degree of Freedom:-",ddof)
alpha = 0.05
chi_square=sum([(o-e)**2./e for o,e in zip(Observed_Values,Expected_Values)])
chi_square_statistic=chi_square[0]+chi_square[1]
print("chi-square statistic:-",chi_square_statistic)
critical_value=chi2.ppf(q=1-alpha,df=ddof)
print('critical_value:',critical_value)#p-value
p_value=1-chi2.cdf(x=chi_square_statistic,df=ddof)
print('p-value:',p_value)
print('Significance level: ',alpha)
print('Degree of Freedom: ',ddof)
print('chi-square statistic:',chi_square_statistic)
print('critical_value:',critical_value)
print('p-value:',p_value)
count=0
if chi_square_statistic>=critical_value:
    print("Reject H0,There is a relationship between 2 categorical variables")
    count=1
else:
    print("Retain H0,There is no relationship between 2 categorical variables")
    
if p_value<=alpha:
    if count==0:
        print("Reject H0,There is a relationship between 2 categorical variables")
else:
    print("Retain H0,There is no relationship between 2 categorical variables")
# Out:
# Degree of Freedom:- 1
# chi-square statistic:- 60.58652461143951
# critical_value: 3.841458820694124
# p-value: 6.994405055138486e-15
# Significance level:  0.05
# Degree of Freedom:  1
# chi-square statistic: 60.58652461143951
# critical_value: 3.841458820694124
# p-value: 6.994405055138486e-15
# Reject H0,There is a relationship between 2 categorical variables
